# %% [markdown]
# # Marginal 1-dim posteriors from image data
#
# - Using SWYFT core functions (i.e. look at swyft/core.py)
# - Demonstrates `head` network
#
# Author: Christoph Weniger and Benjamin Miller, August 2020

# %%
import numpy as np
import pylab as plt
import swyft
import torch
from scipy import stats
# %load_ext autoreload
# %autoreload 2

np.random.seed(25)
torch.manual_seed(25)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DEVICE = 'cuda:0'
NDIM = 2 # number of parameters
NBINS = 1000
SIGMA = 0.01

# %%
# A toy model with a diffuse and point source component

def model(z, sigma = SIGMA, w = 0.4):
    x = z + np.random.randn(2)*sigma + (np.random.rand(2)-0.5)*w
    return x

# %%
z0 = np.array([0.5, 0.5])
x0 = np.array([0.5, 0.5])

# %%
ds = swyft.DataStoreZarr("/home/ubuntu/volume1/zzzz1")
ds.init(zdim = 2, xdim = (2,))
# Out:
# Loading datastore: /home/ubuntu/volume1/zzzz1
# WARNING: Datastore is already initialized.

# %%
# Instantiate network
sw = swyft.LFI(x0, model, zdim = 2, device = DEVICE, head = None, datastore = ds)

# %%
sw.init_train_data(nsamples = 3000)
# Out:
# Constrained posterior area: 1.0
# No new simulator runs required.

# %%
if sw.requires_sim():
    for i in ds.require_sim():
        z = ds.z[i]
        x = model(z)
        ds.add_sim(i, x)

# %%
sw.init_net1d()

# %%
sw.train1d(max_epochs = 10, nbatch = 32)
# Out:
# Start training
# LR iteration 0
# Total epochs: 9
# Validation losses: [3.40339557826519, 3.3213692009449005, 3.30705189704895, 3.3277757614851, 3.3067481368780136, 3.240854248404503, 3.2700237184762955, 3.270319774746895, 3.26456755399704]
# LR iteration 1
# Total epochs: 10
# Validation losses: [3.1593240052461624, 3.1574622690677643, 3.156151160597801, 3.1553824841976166, 3.1546289324760437, 3.1531600058078766, 3.1524225920438766, 3.151728078722954, 3.1508433520793915, 3.150505393743515]
# LR iteration 2
# Total epochs: 10
# Validation losses: [3.1433484256267548, 3.1401465386152267, 3.1388429701328278, 3.1380504816770554, 3.137635514140129, 3.1373613327741623, 3.1371394991874695, 3.136950582265854, 3.136770412325859, 3.1366329193115234]

# %%
sw.eval_post1d()

# %%
plt.figure(figsize=(20, 5))
for i in range(2):
    z, p = sw.posterior(i)
    plt.axvline(z0[i])
    plt.scatter(z, p)

# %%
sw2 = swyft.LFI(x0, model, zdim = 2, device = DEVICE, head = None, datastore = ds, parent = sw)
sw2.init_train_data(nsamples = 10000, threshold = 1e-10)
# Out:
# Constrained posterior area: 0.8387631
# Adding 755 new samples. Run simulator!

# %%
if sw2.requires_sim():
    for i in ds.require_sim():
        z = ds.z[i]
        x = model(z)
        ds.add_sim(i, x)

# %%
sw2.init_net1d()

# %%
sw2.train1d(max_epochs = 1, nbatch = 32)
# Out:
# Start training
# LR iteration 0
# Total epochs: 1
# Validation losses: [3.5768857151269913]
# LR iteration 1
# Total epochs: 1
# Validation losses: [3.5188353806734085]
# LR iteration 2
# Total epochs: 1
# Validation losses: [3.522315636277199]

# %%
sw2.eval_post1d()

# %%
plt.figure(figsize=(20, 5))
for i in range(2):
    z, p = sw2.posterior(i)
    plt.axvline(z0[i])
    plt.scatter(z, p)

# %%
sw2.init_netNd([[0, 1]])

# %%
sw2.trainNd(max_epochs = 10, nbatch = 128)
# Out:
# Start training
# LR iteration 0
# Epoch: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-89050d7b2ea5> in <module>
# ----> 1 sw2.trainNd(max_epochs = 10, nbatch = 128)
#
# ~/volume1/swyft/swyft/interface.py in trainNd(self, max_epochs, nbatch, lr_schedule, nl_schedule, early_stopping_patience, nworkers, tag)
#     150         trainloop(net, dataset, combinations = combinations, device = self.device, max_epochs = max_epochs,
#     151                 nbatch = nbatch, lr_schedule = lr_schedule, nl_schedule =
# --> 152                 nl_schedule, early_stopping_patience = early_stopping_patience, nworkers=nworkers)
#     153
#     154     def init_train_data(self, nsamples = 3000, threshold = 1e-6, res = 1e-4):
#
# ~/volume1/swyft/swyft/interface.py in trainloop(net, dataset, combinations, nbatch, nworkers, max_epochs, early_stopping_patience, device, lr_schedule, nl_schedule)
#      53                 early_stopping_patience = early_stopping_patience, lr = lr,
#      54                 max_epochs = max_epochs, device=device, combinations =
# ---> 55                 combinations)
#      56         vl_minimum = min(vl)
#      57         vl_min_idx = vl.index(vl_minimum)
#
# ~/volume1/swyft/swyft/core.py in train(network, train_loader, validation_loader, early_stopping_patience, max_epochs, lr, combinations, device, non_blocking)
#     381         print("Epoch:", epoch, end = "\r")
#     382         network.train()
# --> 383         train_loss = do_epoch(train_loader, True)
#     384         train_losses.append(train_loss / n_train_batches)
#     385
#
# ~/volume1/swyft/swyft/core.py in do_epoch(loader, train)
#     363                 if device is not None:
#     364                     batch = {k: v.to(device, non_blocking=non_blocking) for k, v in batch.items()}
# --> 365                 loss = loss_fn(network, batch, combinations = combinations)
#     366                 if train:
#     367                     loss.backward()
#
# ~/volume1/swyft/swyft/core.py in loss_fn(network, xz, combinations)
#     297     # repetition is alternating in first dimension: [a, b, a, b, c, d, c, d, ...]
#     298     z = xz['z']
# --> 299     z = torch.stack([combine_z(zs, combinations) for zs in z])
#     300     zdim = len(z[0])
#     301     z = z.view(n_batch // 2, -1, *z.shape[-1:])
#
# ~/volume1/swyft/swyft/core.py in <listcomp>(.0)
#     297     # repetition is alternating in first dimension: [a, b, a, b, c, d, c, d, ...]
#     298     z = xz['z']
# --> 299     z = torch.stack([combine_z(zs, combinations) for zs in z])
#     300     zdim = len(z[0])
#     301     z = z.view(n_batch // 2, -1, *z.shape[-1:])
#
# ~/miniconda3/envs/lens/lib/python3.7/site-packages/torch/tensor.py in <lambda>(i)
#     454                           'iterations executed (and might lead to errors or silently give '
#     455                           'incorrect results).', category=RuntimeWarning)
# --> 456         return iter(map(lambda i: self[i], range(self.size(0))))
#     457
#     458     def __hash__(self):
#
# KeyboardInterrupt:

# %%
sw2.eval_postNd()

# %%
zgrid, lnLgrid = sw2.posterior([0, 1])
plt.scatter(zgrid[:,0], zgrid[:,1], marker='.', color='0.8')
max_lnL = lnLgrid[:].max()
plt.tricontour(zgrid[:,0], zgrid[:,1], (-lnLgrid+max_lnL)*2, levels = [1, 4, 9])
plt.xlim([0, 1])
plt.ylim([0, 1])
# Out:
# (0.0, 1.0)
