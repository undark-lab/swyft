# %% [markdown]
# Discard: Lattice stuff

# %%
import torch
import numpy as np
import pylab as plt

# %%
N = 16
A = np.random.exponential(1., N)
phi = np.random.rand(N)*2*np.pi
K = range(1, N+1)
x = np.linspace(0, 2*np.pi, 32)
phi = sum([(A[k-1]/k**2)**0.5*np.cos(k*x+phi[k-1]) for k in K])

# %%
J = phi**2*0.2 + np.random.randn(len(x))*0.8

# %%
plt.plot(phi)
#plt.plot(J)

# %%
g = phi*np.mean(phi)
np.mean(g)
# Out:
# 0.00037337812600065474
