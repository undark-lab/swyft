# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import torch
from torch import nn
import torch
import time
import unet

from tqdm.auto import tqdm

import swyft
import pylab as plt
import scipy.stats.distributions as dist

torch.set_float32_matmul_precision('medium')
DEVICE = "cuda"

# %% [markdown]
# ### Generative model

# %%
bounds = None

# %%
class SimulatorBlob(swyft.Simulator):
    def __init__(self, bounds = None, bounds_theta = None, Npix = 64, sigma = 0.1):
        super().__init__()
        self.transform_samples = swyft.to_numpy32
        self.theta_sampler = swyft.RectBoundSampler([dist.uniform(3., 2)], bounds = bounds_theta)
        self.bounds = bounds
        self.Npix = Npix
        self.sigma = sigma
        self.powersampler = swyft.utils.PowerSpectrumSampler(Npix)
        self.sigma = torch.ones(Npix, Npix)*0.1
#        self.sigma[:,:Npix//2] *= 1000

    def get_pk_fn(self, theta):
        return lambda k: 1e6*3*(k/0.5)**-theta[0]
        
    def sample_delta(self, pk_fn):
        if self.bounds is not None:
            i = np.random.randint(len(self.bounds))
            return torch.tensor(self.bounds[i])
        else:
#            return self.powersampler.sample(lambda k: 1e6*3*(k/0.5)**-theta[0])
            return self.powersampler.sample(pk_fn)
            
    def build(self, graph):
        theta = graph.node("theta", self.theta_sampler)
        pk_fn = graph.node("pk_fn", self.get_pk_fn, theta)
        delta = graph.node("delta", self.sample_delta, pk_fn)
        rho = graph.node("rho", lambda delta: torch.exp(delta/5), delta)
        x = graph.node("x", lambda rho: rho + torch.randn(self.Npix, self.Npix)*self.sigma, rho)
#        z = graph.node("test", lambda: lambda x: x)

# %%
NPIX = 128
sim = SimulatorBlob(Npix = NPIX)
sample0 = sim.sample(conditions = dict(theta = np.array([3.8])))
plt.figure(figsize = (15, 5))
plt.subplot(131)
plt.imshow(sample0['delta'], cmap = 'inferno')
plt.colorbar()
plt.subplot(132)
plt.imshow(sample0['x'], cmap = 'inferno')
plt.colorbar()
# Out:
# /home/cweniger/.pyenv/versions/3.10.11/lib/python3.10/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
#NPIX = 128
sim = SimulatorBlob(Npix = NPIX, bounds = bounds)
#samples = sim.sample(8)
plt.figure(figsize = (15, 15))
for i in range(8):
    plt.subplot(4, 4, i+1)
    plt.imshow(samples[i]['x'], cmap = 'inferno')
    plt.colorbar()

# %% [markdown]
# ### Inference network

# %%
class Network(swyft.SwyftModule):
    def __init__(self, lr=1e-3, N = 1024):
        super().__init__()
        self.optimizer_init = swyft.AdamOptimizerInit(lr=1e-4, lrs_factor=0.1, lrs_patience=3)
        self.N = N
        L = lambda x: x*0
        self.Phi = lambda x: x
        self.PhiT = lambda x: x
        self.lre = swyft.LogRatioEstimator_Gaussian_Autoregressive_X_module_based(
            self.N**2, "mu", Phi = self.Phi, PhiT = self.PhiT, L = L, minstd = 1e-5, momentum=0.02)
        self.lre2 = swyft.LogRatioEstimator_1dim(2, 1, 'theta')
        self.unet = unet.UNet(1, 1, s = 4)
        self.cnn = torch.nn.Sequential(
            torch.nn.LazyConv2d(4, 3), torch.nn.ReLU(), torch.nn.MaxPool2d(2),
            torch.nn.LazyConv2d(8, 3), torch.nn.ReLU(), torch.nn.MaxPool2d(2),
            torch.nn.LazyConv2d(16, 3), torch.nn.ReLU(), torch.nn.MaxPool2d(2),
            torch.nn.LazyConv2d(32, 3), torch.nn.ReLU(), torch.nn.MaxPool2d(2),
            torch.nn.LazyConv2d(64, 3)
        )
        self.l = torch.nn.LazyLinear(2)
    
    def embed(self, x):
        x = self.unet(x.unsqueeze(1)).squeeze(1) + x
        x = x.view(-1, self.N**2)
        return x
    
    def ps_estimator(self, x):
        f = self.cnn(x.unsqueeze(1))
        f = self.l(f.flatten(start_dim=1))
        return f

    def forward(self, A, B):
        N = self.N
        if 'x' in B.keys():
            rhoA = self.embed(A['x'])
            rhoB = self.embed(B['x'])
            deltaB = B['delta'].view(-1, N**2)
            result = self.lre(rhoA, rhoB, deltaB)
        else:
            result = None
        
        f = self.ps_estimator(A['x'])
        result2 = self.lre2(f, B['theta'])

        return result2#, result

# %% [markdown]
# ### Inference

# %%
#sim = SimulatorBlob(Npix = NPIX, bounds = bounds)
#samples = sim.sample(1000, exclude = ['pk_fn'])
#net.cpu(); net.float()
dm = swyft.SwyftDataModule(samples, fractions = [0.9, 0.1, 0.0], batch_size = 64)
net = Network(N = NPIX)
trainer = swyft.SwyftTrainer(accelerator = "gpu", devices = 1, max_epochs = 40)
trainer.fit(net, dm)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type                                                     | Params
# ----------------------------------------------------------------------------------
# 0 | lre  | LogRatioEstimator_Gaussian_Autoregressive_X_module_based | 0
# 1 | lre2 | LogRatioEstimator_1dim                                   | 17.5 K
# 2 | unet | UNet                                                     | 1.9 M
# 3 | cnn  | Sequential                                               | 0
# 4 | l    | LazyLinear                                               | 0
# ----------------------------------------------------------------------------------
# 2.0 M     Trainable params
# 0         Non-trainable params
# 2.0 M     Total params
# 7.839     Total estimated model params size (MB)
# Epoch 0:  88%|█████████████████████████████████████████████████████████████████████▋         | 15/17 [00:01<00:00, 10.25it/s, loss=0.00119, v_num=259]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 0:  94%|██████████████████████████████████████████████████████████████████████████▎    | 16/17 [00:01<00:00, 10.28it/s, loss=0.00119, v_num=259]
# Epoch 0: 100%|█████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.51it/s, loss=0.00119, v_num=259, val_loss=0.00223]
# Epoch 1:  88%|████████████████████████████████████████████████████▉       | 15/17 [00:01<00:00, 10.49it/s, loss=0.000273, v_num=259, val_loss=0.00223]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 1:  94%|████████████████████████████████████████████████████████▍   | 16/17 [00:01<00:00, 10.54it/s, loss=0.000273, v_num=259, val_loss=0.00223]
# Epoch 1: 100%|████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.65it/s, loss=0.000273, v_num=259, val_loss=0.00162]
# Epoch 2:  88%|████████████████████████████████████████████████████▉       | 15/17 [00:01<00:00, 10.55it/s, loss=9.38e-05, v_num=259, val_loss=0.00162]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 2:  94%|████████████████████████████████████████████████████████▍   | 16/17 [00:01<00:00, 10.57it/s, loss=9.38e-05, v_num=259, val_loss=0.00162]
# Epoch 2: 100%|███████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.74it/s, loss=9.38e-05, v_num=259, val_loss=0.000926]
# Epoch 3:  88%|███████████████████████████████████████████████████▏      | 15/17 [00:01<00:00, 10.44it/s, loss=-0.000408, v_num=259, val_loss=0.000926]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 3:  94%|██████████████████████████████████████████████████████▌   | 16/17 [00:01<00:00, 10.47it/s, loss=-0.000408, v_num=259, val_loss=0.000926]
# Epoch 3: 100%|██████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.54it/s, loss=-0.000408, v_num=259, val_loss=0.000103]
# Epoch 4:  88%|████████████████████████████████████████████████████       | 15/17 [00:01<00:00, 10.45it/s, loss=-0.00345, v_num=259, val_loss=0.000103]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 4:  94%|███████████████████████████████████████████████████████▌   | 16/17 [00:01<00:00, 10.50it/s, loss=-0.00345, v_num=259, val_loss=0.000103]
# Epoch 4: 100%|███████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.64it/s, loss=-0.00345, v_num=259, val_loss=0.000962]
# Epoch 5:  88%|████████████████████████████████████████████████████▉       | 15/17 [00:01<00:00, 10.63it/s, loss=-0.0103, v_num=259, val_loss=0.000962]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 5:  94%|████████████████████████████████████████████████████████▍   | 16/17 [00:01<00:00, 10.67it/s, loss=-0.0103, v_num=259, val_loss=0.000962]
# Epoch 5: 100%|█████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.81it/s, loss=-0.0103, v_num=259, val_loss=-.00225]
# Epoch 6:  88%|█████████████████████████████████████████████████████▊       | 15/17 [00:01<00:00, 10.42it/s, loss=-0.0218, v_num=259, val_loss=-.00225]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 6:  94%|█████████████████████████████████████████████████████████▍   | 16/17 [00:01<00:00, 10.42it/s, loss=-0.0218, v_num=259, val_loss=-.00225]
# Epoch 6: 100%|█████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.58it/s, loss=-0.0218, v_num=259, val_loss=-.00916]
# Epoch 7:  88%|█████████████████████████████████████████████████████▊       | 15/17 [00:01<00:00,  9.90it/s, loss=-0.0481, v_num=259, val_loss=-.00916]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 7:  94%|█████████████████████████████████████████████████████████▍   | 16/17 [00:01<00:00,  9.96it/s, loss=-0.0481, v_num=259, val_loss=-.00916]
# Epoch 7: 100%|█████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.10it/s, loss=-0.0481, v_num=259, val_loss=0.00389]
# Epoch 8:  88%|██████████████████████████████████████████████████████▋       | 15/17 [00:01<00:00, 10.25it/s, loss=-0.113, v_num=259, val_loss=0.00389]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 8:  94%|██████████████████████████████████████████████████████████▎   | 16/17 [00:01<00:00, 10.29it/s, loss=-0.113, v_num=259, val_loss=0.00389]
# Epoch 8: 100%|████████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.52it/s, loss=-0.113, v_num=259, val_loss=0.191]
# Epoch 9:  88%|████████████████████████████████████████████████████████▍       | 15/17 [00:01<00:00, 10.08it/s, loss=-0.233, v_num=259, val_loss=0.191]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 9:  94%|████████████████████████████████████████████████████████████▏   | 16/17 [00:01<00:00, 10.08it/s, loss=-0.233, v_num=259, val_loss=0.191]
# Epoch 9: 100%|████████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.26it/s, loss=-0.233, v_num=259, val_loss=0.958]
# Epoch 10:  88%|███████████████████████████████████████████████████████▌       | 15/17 [00:01<00:00, 10.59it/s, loss=-0.381, v_num=259, val_loss=0.958]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 10:  94%|███████████████████████████████████████████████████████████▎   | 16/17 [00:01<00:00, 10.64it/s, loss=-0.381, v_num=259, val_loss=0.958]
# Epoch 10: 100%|███████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.87it/s, loss=-0.381, v_num=259, val_loss=1.310]
# Epoch 10: 100%|███████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.84it/s, loss=-0.381, v_num=259, val_loss=1.310]Epoch 00011: reducing learning rate of group 0 to 1.0000e-05.
# Epoch 11:  88%|███████████████████████████████████████████████████████▌       | 15/17 [00:01<00:00, 10.37it/s, loss=-0.471, v_num=259, val_loss=1.310]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 11:  94%|███████████████████████████████████████████████████████████▎   | 16/17 [00:01<00:00, 10.42it/s, loss=-0.471, v_num=259, val_loss=1.310]
# Epoch 11: 100%|███████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.54it/s, loss=-0.471, v_num=259, val_loss=0.341]
# Epoch 12:  88%|████████████████████████████████████████████████████████▍       | 15/17 [00:01<00:00, 10.56it/s, loss=-0.49, v_num=259, val_loss=0.341]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 12:  94%|████████████████████████████████████████████████████████████▏   | 16/17 [00:01<00:00, 10.60it/s, loss=-0.49, v_num=259, val_loss=0.341]
# Epoch 12: 100%|████████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.72it/s, loss=-0.49, v_num=259, val_loss=-.343]
# Epoch 13:  88%|███████████████████████████████████████████████████████▌       | 15/17 [00:01<00:00, 10.32it/s, loss=-0.498, v_num=259, val_loss=-.343]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 13:  94%|███████████████████████████████████████████████████████████▎   | 16/17 [00:01<00:00, 10.38it/s, loss=-0.498, v_num=259, val_loss=-.343]
# Epoch 13: 100%|███████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.58it/s, loss=-0.498, v_num=259, val_loss=-.377]
# Epoch 14:  88%|███████████████████████████████████████████████████████▌       | 15/17 [00:01<00:00, 10.44it/s, loss=-0.513, v_num=259, val_loss=-.377]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 14:  94%|███████████████████████████████████████████████████████████▎   | 16/17 [00:01<00:00, 10.49it/s, loss=-0.513, v_num=259, val_loss=-.377]
# Epoch 14: 100%|███████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.66it/s, loss=-0.513, v_num=259, val_loss=-.417]
# Epoch 15:  88%|███████████████████████████████████████████████████████▌       | 15/17 [00:01<00:00, 10.47it/s, loss=-0.524, v_num=259, val_loss=-.417]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 15:  94%|███████████████████████████████████████████████████████████▎   | 16/17 [00:01<00:00, 10.53it/s, loss=-0.524, v_num=259, val_loss=-.417]
# Epoch 15: 100%|███████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.76it/s, loss=-0.524, v_num=259, val_loss=-.436]
# Epoch 16:  88%|███████████████████████████████████████████████████████▌       | 15/17 [00:01<00:00, 10.60it/s, loss=-0.529, v_num=259, val_loss=-.436]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 16:  94%|███████████████████████████████████████████████████████████▎   | 16/17 [00:01<00:00, 10.65it/s, loss=-0.529, v_num=259, val_loss=-.436]
# Epoch 16: 100%|███████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.81it/s, loss=-0.529, v_num=259, val_loss=-.456]
# Epoch 17:  88%|███████████████████████████████████████████████████████▌       | 15/17 [00:01<00:00, 10.54it/s, loss=-0.541, v_num=259, val_loss=-.456]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 17:  94%|███████████████████████████████████████████████████████████▎   | 16/17 [00:01<00:00, 10.58it/s, loss=-0.541, v_num=259, val_loss=-.456]
# Epoch 17: 100%|███████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.70it/s, loss=-0.541, v_num=259, val_loss=-.427]
# Epoch 18:  88%|███████████████████████████████████████████████████████▌       | 15/17 [00:01<00:00, 10.30it/s, loss=-0.548, v_num=259, val_loss=-.427]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                                                               | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                                                  | 0/2 [00:00<?, ?it/s]
# Epoch 18:  94%|███████████████████████████████████████████████████████████▎   | 16/17 [00:01<00:00, 10.35it/s, loss=-0.548, v_num=259, val_loss=-.427]
# Epoch 18: 100%|███████████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 10.50it/s, loss=-0.548, v_num=259, val_loss=-.486]
# Epoch 19:  65%|████████████████████████████████████████▊                      | 11/17 [00:01<00:00, 10.24it/s, loss=-0.542, v_num=259, val_loss=-.486]

# %% [markdown]
# ### Evaluation

# %%
sim = SimulatorBlob(Npix=128, bounds_theta = bounds_theta)
prior_samples = sim.sample(10000, targets = ["theta"])
s = swyft.Sample(x = sample0['x'])
results = trainer.infer(net, s, prior_samples)
# Out:
#   0%|                                                                                                                       | 0/10000 [00:00<?, ?it/s]
#   8%|████████▉                                                                                                  | 841/10000 [00:00<00:01, 8404.52it/s]
#  17%|██████████████████▎                                                                                       | 1725/10000 [00:00<00:00, 8658.71it/s]
#  28%|█████████████████████████████▏                                                                            | 2752/10000 [00:00<00:00, 9391.71it/s]
#  37%|███████████████████████████████████████▏                                                                  | 3692/10000 [00:00<00:00, 9116.55it/s]
#  48%|██████████████████████████████████████████████████▍                                                       | 4761/10000 [00:00<00:00, 9670.87it/s]
#  58%|█████████████████████████████████████████████████████████████▋                                            | 5824/10000 [00:00<00:00, 9990.94it/s]
#  69%|████████████████████████████████████████████████████████████████████████▎                                | 6892/10000 [00:00<00:00, 10212.58it/s]
#  80%|███████████████████████████████████████████████████████████████████████████████████▌                     | 7963/10000 [00:00<00:00, 10369.38it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [00:01<00:00, 9996.57it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100%|████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 98.52it/s]

# %%
swyft.plot_1d(results, 'theta[0]', smooth = 1)
plt.axvline(3.8, color='r')
bounds_theta = swyft.collect_rect_bounds(results[0], 'theta', (1,), threshold = 1e-3)
print(bounds_theta)
# Out:
# tensor([[3.5409, 4.0388]])

# %%
GAMMA = 0.01

x = sample0['x']
y = net.cuda().double().embed(torch.tensor(x).cuda().double().unsqueeze(0))[0]
draws = []
thetas = []

for i in tqdm(range(1000)):
    s = SimulatorBlob(bounds_theta = bounds_theta, Npix = NPIX).sample()
    pk = s['pk_fn']
    theta = s['theta']
    prior = sim.powersampler.get_prior_Q_factors(pk)
    prior = (prior[0], prior[1].cuda(), prior[2])
    x0 = net.lre.get_MAP(y, prior, gamma = GAMMA)
    draw = net.lre.get_noise_samples_GEDA(1, prior, steps = 500, reset = True, gamma = GAMMA)
    draws.append(draw[0].detach().cpu())
    thetas.append(theta)
# Out:
#   0%|                                                                                                                        | 0/1000 [00:00<?, ?it/s]
#   0%|                                                                                                                | 1/1000 [00:00<09:01,  1.84it/s]
#   0%|▏                                                                                                               | 2/1000 [00:01<10:21,  1.61it/s]
#   0%|▎                                                                                                               | 3/1000 [00:01<09:08,  1.82it/s]
#   0%|▍                                                                                                               | 4/1000 [00:02<08:23,  1.98it/s]
#   0%|▌                                                                                                               | 5/1000 [00:02<08:56,  1.85it/s]
#   1%|▋                                                                                                               | 6/1000 [00:03<09:37,  1.72it/s]
#   1%|▊                                                                                                               | 7/1000 [00:03<09:36,  1.72it/s]
#   1%|▉                                                                                                               | 8/1000 [00:05<12:02,  1.37it/s]
#   1%|█                                                                                                               | 9/1000 [00:05<10:38,  1.55it/s]
#   1%|█                                                                                                              | 10/1000 [00:06<10:45,  1.53it/s]
#   1%|█▏                                                                                                             | 11/1000 [00:06<10:45,  1.53it/s]
#   1%|█▎                                                                                                             | 12/1000 [00:07<12:22,  1.33it/s]
#   1%|█▍                                                                                                             | 13/1000 [00:08<11:00,  1.49it/s]
#   1%|█▌                                                                                                             | 14/1000 [00:08<10:49,  1.52it/s]
#   2%|█▋                                                                                                             | 15/1000 [00:09<10:33,  1.56it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[162], line 14
#      12 prior = sim.powersampler.get_prior_Q_factors(pk)
#      13 prior = (prior[0], prior[1].cuda(), prior[2])
# ---> 14 x0 = net.lre.get_MAP(y, prior, gamma = GAMMA)
#      15 draw = net.lre.get_noise_samples_GEDA(1, prior, steps = 500, reset = True, gamma = GAMMA)
#      16 draws.append(draw[0].detach().cpu())
#
# File ~/swyft/swyft/lightning/estimators.py:1273, in LogRatioEstimator_Gaussian_Autoregressive_X_module_based.get_MAP(self, x, prior, gamma)
#    1270     return x.view(1, -1, 1).detach()
#    1272 cg = swyft.utils.CG(A, rtol = 0.001, verbose = False, maxiter = 10000)
# -> 1273 x0 = cg.forward(B0)
#    1274 return x0
#
# File ~/swyft/swyft/utils/cg.py:130, in CG.forward(self, B, X0)
#     129 def forward(self, B, X0=None):
# --> 130     X, _ = cg_batch(self.A_bmm, B, M_bmm=self.M_bmm, X0=X0, rtol=self.rtol,
#     131                  atol=self.atol, maxiter=self.maxiter, verbose=self.verbose)
#     132     return X
#
# File ~/swyft/swyft/utils/cg.py:87, in cg_batch(A_bmm, B, M_bmm, X0, rtol, atol, maxiter, verbose)
#      85 alpha = (R_k1 * Z_k1).sum(1) / denominator
#      86 X_k = X_k1 + alpha.unsqueeze(1) * P_k
# ---> 87 R_k = R_k1 - alpha.unsqueeze(1) * A_bmm(P_k)
#      88 end_iter = time.perf_counter()
#      90 residual_norm = torch.norm(A_bmm(X_k) - B, dim=1)
#
# File ~/swyft/swyft/lightning/estimators.py:1270, in LogRatioEstimator_Gaussian_Autoregressive_X_module_based.get_MAP.<locals>.A(x)
#    1268 x = x[0,:,0]
#    1269 x = prior_Q(x) + like_Q(x)
# -> 1270 return x.view(1, -1, 1).detach()
#
# KeyboardInterrupt:

# %%
bounds = [(x0.view(NPIX, NPIX).cpu().detach() + draws[i].view(NPIX, NPIX).cpu()).numpy() for i in range(len(draws))]
bounds = np.array(bounds)
thetas = np.array(thetas)

# %% [markdown]
# ### Round 0

# %%
v = 15
plt.figure(figsize = (15, 5))
for i in range(4):
    plt.subplot(2, 4, i+1)
    if i == 0:
        plt.imshow(sample0['delta'], cmap = 'seismic', vmin = -v, vmax = v)
    else:
        plt.imshow(bounds[i], vmin = -v, vmax = v, cmap = 'seismic')
    plt.colorbar()    
res = [(x0.view(NPIX, NPIX).cpu().detach()*0 + draws[i].view(NPIX, NPIX).cpu()).numpy() for i in range(len(draws))]
for i in range(4):
    plt.subplot(2, 4, i+1+4)
    plt.imshow(res[i], vmin = -v, vmax = v, cmap = 'seismic')
    plt.colorbar()

# %%
sim2 = SimulatorBlob(Npix=128)
def c_sampler():
    i = np.random.randint(300)
    return dict(theta = torch.tensor(thetas[i]), delta = torch.tensor(bounds[i]))

samples = sim2.sample(1000, conditions = c_sampler,  exclude = ['pk_fn'])
# Out:
#   0%|                                                                                                                        | 0/1000 [00:00<?, ?it/s]
#  32%|██████████████████████████████████▋                                                                         | 321/1000 [00:00<00:00, 3203.11it/s]
#  64%|█████████████████████████████████████████████████████████████████████▎                                      | 642/1000 [00:00<00:00, 2950.34it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 2653.07it/s]
