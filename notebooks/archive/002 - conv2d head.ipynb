# %% [markdown]
# # Contrastive learning density estimation
#
# Author: Christoph Weniger, June 2020
#
# Math behind this can be found here: https://www.notion.so/cweniger/The-math-of-contrastive-learning-6991de9a04c74d84be61239717fdb57c
#
# ## Purpose
#
# - Prototype for systematically test and compare density estimation models

# %%
import numpy as np
import pylab as plt
import swyft
import torch

# %%
def model(z, sigma = 0.1):
    x = np.linspace(-5, 5, 30)
    X, Y = np.meshgrid(x,x)
    t1 = np.cos(X)*np.cos(Y)*z[0]
    t2 = np.cos(X)*np.sin(Y)*z[1]
    n = np.random.randn(*t1.shape)*sigma
    return (t1 + t2 + n)

x0 = model(np.array([0.2, .8, 0.5]), sigma = 0.01)

# %%
plt.imshow(x0)

# %%
class Head(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(1, 10, 3)
        self.conv2 = torch.nn.Conv2d(10, 20, 3)
        self.pool = torch.nn.MaxPool2d(2)
        
    def forward(self, x):
        x = x.unsqueeze(0).unsqueeze(0)
        x = self.conv1(x)
        x = self.pool(x)
        x = self.conv2(x)
        x = self.pool(x)
        return x.flatten()

# %%
sw = swyft.SWYFT(model, 3, x0, device = 'cuda:0')

# %%
sw.round(n_sims = 1000, n_train = 3000, lr = 1e-4, head = Head().cuda(), p = 0.5)
sw.round(n_sims = 1000, n_train = 3000, lr = 1e-4, head = Head().cuda(), p = 0.5)
# Out:
#  28%|██▊       | 281/1000 [00:00<00:00, 2809.46it/s]
# Round:  0
# Generate samples from constrained prior: z~pc(z)
# Generate corresponding draws x ~ p(x|z)
# 100%|██████████| 1000/1000 [00:00<00:00, 2815.42it/s]
#   0%|          | 4/3000 [00:00<01:22, 36.30it/s]
# Network optimization
# 100%|██████████| 3000/3000 [01:00<00:00, 49.45it/s]
# Round:  1
# Generate samples from constrained prior: z~pc(z)
#  28%|██▊       | 277/1000 [00:00<00:00, 2761.61it/s]
# Constrained posterior volume: 0.28667699999999996
# Generate corresponding draws x ~ p(x|z)
# 100%|██████████| 1000/1000 [00:00<00:00, 2695.74it/s]
#   0%|          | 6/3000 [00:00<00:54, 54.89it/s]
# Network optimization
# 100%|██████████| 3000/3000 [01:00<00:00, 49.52it/s]

# %%
post0 = sw.get_posteriors(nround=0)
post1 = sw.get_posteriors(nround=1)

# %%
for i in range(3):
    plt.plot(post0[i]['z'], np.exp(post0[i]['lnL']))
for i in range(3):
    plt.plot(post1[i]['z'], np.exp(post1[i]['lnL']))
#plt.plot(post1[0]['z'], np.exp(post1[0]['lnL']))
#plt.plot(post2[0]['z'], np.exp(post2[0]['lnL']))
#plt.plot(post3[0]['z'], np.exp(post3[0]['lnL']))

# %%
x = sw.xz_store[0][2]['x']
plt.imshow(x)

# %%
y = []
for i in range(1):
    post1 = sw.get_posteriors(nround=1, MC_dropout = True)
    y.append(post1[0]['lnL'])
    x = post1[0]['z']

# %%
ys = sum(y)/10
plt.plot(x, y[0])
plt.xlim([0.1, 0.3])
plt.ylim([-15, 0])
# Out:
# (-15.0, 0.0)

# %%
sw.round(n_sims = 5000, n_train = 6000, lr = 1e-4, head = Head().cuda(), p = 0.1)
# Out:
# Round:  7
# Generate samples from constrained prior: z~pc(z)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-0b31b202f9f8> in <module>
# ----> 1 sw.round(n_sims = 5000, n_train = 6000, lr = 1e-4, head = Head().cuda(), p = 0.1)
#
# ~/swyft/swyft/swyft.py in round(self, n_sims, n_train, lr, n_particles, head, combine, p)
#      32                 z = sample_z(n_sims, self.z_dim)  # draw from initial prior
#      33             else:
# ---> 34                 z = iter_sample_z(n_sims, self.z_dim, self.net_store[-1], self.x0, device = self.device, verbosity = self.verbose)
#      35
#      36             # time sink
#
# ~/swyft/swyft/core.py in iter_sample_z(n_draws, n_dim, net, x0, device, verbosity)
#     298     while not done:
#     299         z = sample_z(n_draws, n_dim)
# --> 300         zlnL = estimate_lnL(net, x0, z, sort = False, device = device)
#     301         for i in range(n_dim):
#     302             mask = zlnL[i]['lnL'] > -13
#
# ~/swyft/swyft/core.py in estimate_lnL(network, x0, z, L_th, n_train, epsilon, n_sub, sort, device)
#      77     n_dim = z[0].shape[0]
#      78     x0 = torch.tensor(x0).float().to(device)
# ---> 79     lnL = [network(x0, torch.tensor(z[i]).float().to(device)).detach().cpu().numpy() for i in range(len(z))]
#      80     out = []
#      81     for i in range(n_dim):
#
# ~/swyft/swyft/core.py in <listcomp>(.0)
#      77     n_dim = z[0].shape[0]
#      78     x0 = torch.tensor(x0).float().to(device)
# ---> 79     lnL = [network(x0, torch.tensor(z[i]).float().to(device)).detach().cpu().numpy() for i in range(len(z))]
#      80     out = []
#      81     for i in range(n_dim):
#
# ~/miniconda3/envs/lens/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/swyft/swyft/core.py in forward(self, x, z)
#     273
#     274         if self.head is not None:
# --> 275             x = self.head(x)
#     276         out = self.legs(x, z)
#     277         return out
#
# ~/miniconda3/envs/lens/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# <ipython-input-4-fe9b114b8868> in forward(self, x)
#      10         x = self.conv1(x)
#      11         x = self.pool(x)
# ---> 12         x = self.conv2(x)
#      13         x = self.pool(x)
#      14         return x.flatten()
#
# ~/miniconda3/envs/lens/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/lens/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     343
#     344     def forward(self, input):
# --> 345         return self.conv2d_forward(input, self.weight)
#     346
#     347 class Conv3d(_ConvNd):
#
# ~/miniconda3/envs/lens/lib/python3.7/site-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     340                             _pair(0), self.dilation, self.groups)
#     341         return F.conv2d(input, weight, self.bias, self.stride,
# --> 342                         self.padding, self.dilation, self.groups)
#     343
#     344     def forward(self, input):
#
# KeyboardInterrupt:

# %%
post2 = sw.get_posteriors(nround=6, MC_dropout = True)
y = post2[0]['lnL']
x = post2[0]['z']
plt.plot(x, y)
plt.xlim([0.1, 0.3])
plt.ylim([-15, 0])
# Out:
# (-15.0, 0.0)
